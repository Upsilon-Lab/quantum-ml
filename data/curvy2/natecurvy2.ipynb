# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
size = 128 # size of output vector
x = np.linspace(0,1,size) # x-values to plot
rand = lambda : np.random.randint(0,100) # random number function

smooth = 5 # smoothness
## 1 is very spiky, 5 is average, 20 is very smooth ##

f = 0 # initialize vector
r = np.random.randint(10,100) # set random number of curves
for n in range(0,r):
    f = f + (rand()/50)/r * np.cos( (rand()/smooth) * np.pi * x + rand())
    ## make sure amplitude, frequency and phase vary ##

f += 0.5 # make sure function is positive (because of OCD)

plt.axis([0, 1,min(f)-0.2,max(f)+0.2]) # set axes
plt.plot(x,f) # plot

# %%
print(f) # print the entire vector for the curvy function
# Out:
# [0.61084849 0.56819402 0.52024371 0.47325841 0.43345628 0.40601672
#  0.39425799 0.39912687 0.41908129 0.45037639 0.48769545 0.52501099
#  0.55652823 0.57755611 0.58517133 0.57858151 0.55914695 0.53007674
#  0.49586421 0.46156209 0.43201455 0.41116132 0.40150997 0.40384109
#  0.41717372 0.43897981 0.46560356 0.49281628 0.51642404 0.53284254
#  0.5395631  0.53545107 0.52084304 0.49743706 0.46799891 0.43593188
#  0.40477622 0.3777131  0.35714629 0.34442171 0.33972288 0.34215163
#  0.34997324 0.36097821 0.37289413 0.38377445 0.39229707 0.3979249
#  0.4009081  0.40213899 0.40289895 0.40455639 0.40828149 0.41483591
#  0.4244754  0.43697507 0.4517574  0.46807859 0.48521648 0.50260473
#  0.51987484 0.53679432 0.5531212  0.56842233 0.58191927 0.5924256
#  0.59842139 0.59827836 0.59060874 0.57467243 0.55075001 0.5203818
#  0.4863891  0.45263181 0.42351054 0.40327926 0.3952851  0.40128139
#  0.42096118 0.45182787 0.48946138 0.52816279 0.56188261 0.58527367
#  0.5946742  0.58882793 0.56918954 0.53973715 0.50630723 0.47556135
#  0.45377053 0.44564503 0.45343541 0.4764836  0.51131909 0.55229063
#  0.59261906 0.62567267 0.64622079 0.65142266 0.64135913 0.61900237
#  0.58962896 0.55979005 0.53603901 0.52366342 0.52566655 0.54219267
#  0.57050243 0.60549649 0.64067892 0.66936877 0.68592404 0.68674542
#  0.67087622 0.64009828 0.59852507 0.55178997 0.50600275 0.46668422
#  0.43788291 0.42163105 0.41782097 0.42449393 0.43845083 0.45603416
#  0.47390542 0.48965469]
