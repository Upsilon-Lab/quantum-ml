# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
size = 128 # size of output vector
x = np.linspace(0,1,size) # x-values to plot
rand = lambda : np.random.randint(0,100) # random number function

smooth = 5 # smoothness
## 1 is very spiky, 5 is average, 20 is very smooth ##

f = 0 # initialize vector
r = np.random.randint(10,100) # set random number of curves
for n in range(0,r):
    f = f + (rand()/50)/r * np.cos( (rand()/smooth) * np.pi * x + rand())
    ## make sure amplitude, frequency and phase vary ##

f += 0.5 # make sure function is positive (because of OCD)

plt.axis([0, 1,min(f)-0.2,max(f)+0.2]) # set axes
plt.plot(x,f) # plot

# %%
print(f) # print the entire vector for the curvy function
# Out:
# [0.43043967 0.44663649 0.46038569 0.47128614 0.47905224 0.48355415
#  0.48488167 0.48341459 0.47987336 0.47532199 0.47110175 0.46868893
#  0.46948911 0.47460027 0.48459109 0.49934553 0.51801742 0.53911913
#  0.56074146 0.58087101 0.59774673 0.61018223 0.61778246 0.62100106
#  0.62101698 0.61944849 0.6179612  0.6178549  0.61972455 0.62327981
#  0.62737601 0.6302632  0.63000886 0.62500517 0.61444466 0.59864598
#  0.57913719 0.55845274 0.53966407 0.52572717 0.51878088 0.51955311
#  0.52702202 0.53843523 0.5497189  0.55622518 0.5536869  0.53919249
#  0.51197337 0.47381977 0.42900525 0.38369466 0.34491681 0.31927881
#  0.31166451 0.32417746 0.35555483 0.40119559 0.45383031 0.5047324
#  0.54525845 0.56843127 0.57026044 0.55053719 0.51293653 0.46439169
#  0.4138486  0.37063179 0.34273288 0.33535186 0.34997382 0.38415976
#  0.4320891  0.48574212 0.53648334 0.5767277  0.60135652 0.60860327
#  0.60023889 0.58103061 0.5575969  0.53690426 0.52472273 0.52436299
#  0.53595654 0.55642561 0.58014514 0.60015486 0.6096665  0.60355126
#  0.579499   0.53861054 0.48530339 0.42655304 0.3706277  0.32557557
#  0.29776963 0.29079712 0.30490488 0.33709287 0.38181444 0.43211959
#  0.48099313 0.52260972 0.5532565  0.57175477 0.57932477 0.57895857
#  0.57446806 0.56943751 0.56632042 0.56587811 0.56707352 0.56742737
#  0.5637393  0.55299686 0.53325687 0.50429377 0.46786589 0.42753715
#  0.38809155 0.35466614 0.33178752 0.32251462 0.32786384 0.34662883
#  0.37562188 0.41027542]
